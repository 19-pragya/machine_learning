# %%
import pandas as pd

# %%
pd.read_csv('datasets/IPL Data.csv')
# Out:
#     S.No Set No    Set           Name  Country   Playing Role  IPL Matches  \
# 0      1      1    BA1     Chris Lynn      NaN        Batsman         41.0
# 1      2      1    BA1    Eoin Morgan      NaN        Batsman         52.0
# 2      3      1    BA1  Robin Uthappa      NaN        Batsman        177.0
# 3      4      1    BA1      Jason Roy      NaN        Batsman          8.0
# 4      5      1    BA1    Aaron Finch      NaN        Batsman         75.0
# ..   ...    ...    ...            ...      ...            ...          ...
# 57    58  [REC]  [REC]    Lalit Yadav      NaN    All Rounder          NaN
# 58    59  [REC]  [REC]  Shahbaz Ahmed      NaN  Wicket Keeper          NaN
# 59    60  [REC]  [REC]    Nikhil Naik      NaN  Wicket Keeper          3.0
# 60    61  [REC]  [REC]     Tom Curran      NaN    All Rounder          5.0
# 61    62  [REC]  [REC]    Isuru Udana      NaN    All Rounder          NaN
#
#    Capped / Uncapped /Associate  Reserve Price(in ₹ Lacs)  \
# ...

# %%
ipl_auction_df = pd.read_csv('datasets/IPL Data.csv')

# %%
type(ipl_auction_df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max_columns',7)

# %%
ipl_auction_df.head()
# Out:
#    S.No Set No  Set  ... Auctioned Price(in ₹ Lacs)  IPL 2019 Team  \
# 0     1      1  BA1  ...                        200            KKR
# 1     2      1  BA1  ...                        525            NaN
# 2     3      1  BA1  ...                        300            KKR
# 3     4      1  BA1  ...                        150            NaN
# 4     5      1  BA1  ...                        440            NaN
#
#                       IPL Team(s)
# 0         Deccan Chargers,SRH,KKR
# 1             RCB, KKR, SRH, KXIP
# 2               MI, RCB, PWI, KKR
# 3                           GL,DD
# 4  RR, DD, PWI, SRH, MI, GL, KXIP
#
# [5 rows x 13 columns]

# %%
list(ipl_auction_df.columns)
# Out:
# ['S.No',
#  'Set No',
#  'Set',
#  'Name',
#  'Country',
#  'Playing Role',
#  'IPL Matches',
#  'Capped / Uncapped /Associate',
#  'Reserve Price(in ₹ Lacs)',
#  'IPL 2020 Team',
#  'Auctioned Price(in ₹ Lacs)',
#  'IPL 2019 Team',
#  'IPL Team(s)']

# %%
ipl_auction_df.head().transpose()
# Out:
#                                                     0                      1  \
# S.No                                                1                      2
# Set No                                              1                      1
# Set                                               BA1                    BA1
# Name                                       Chris Lynn            Eoin Morgan
# Country                                           NaN                    NaN
# Playing Role                                  Batsman                Batsman
# IPL Matches                                      41.0                   52.0
# Capped / Uncapped /Associate                   Capped                 Capped
# Reserve Price(in ₹ Lacs)                          200                    200
# IPL 2020 Team                          Mumbai Indians  Kolkata Knight Riders
# Auctioned Price(in ₹ Lacs)                        200                    525
# ...

# %%
ipl_auction_df.shape
# Out:
# (62, 13)

# %%
ipl_auction_df.info
# Out:
# <bound method DataFrame.info of     S.No Set No    Set  ... Auctioned Price(in ₹ Lacs)  IPL 2019 Team  \
# 0      1      1    BA1  ...                        200            KKR
# 1      2      1    BA1  ...                        525            NaN
# 2      3      1    BA1  ...                        300            KKR
# 3      4      1    BA1  ...                        150            NaN
# 4      5      1    BA1  ...                        440            NaN
# ..   ...    ...    ...  ...                        ...            ...
# 57    58  [REC]  [REC]  ...                         20            NaN
# 58    59  [REC]  [REC]  ...                         20            NaN
# 59    60  [REC]  [REC]  ...                         20            KKR
# 60    61  [REC]  [REC]  ...                        100            NaN
# 61    62  [REC]  [REC]  ...                         50            NaN
#
#                        IPL Team(s)
# 0          Deccan Chargers,SRH,KKR
# ...

# %%
ipl_auction_df[1:5]
# Out:
#    S.No Set No  Set  ... Auctioned Price(in ₹ Lacs)  IPL 2019 Team  \
# 1     2      1  BA1  ...                        525            NaN
# 2     3      1  BA1  ...                        300            KKR
# 3     4      1  BA1  ...                        150            NaN
# 4     5      1  BA1  ...                        440            NaN
#
#                       IPL Team(s)
# 1             RCB, KKR, SRH, KXIP
# 2               MI, RCB, PWI, KKR
# 3                           GL,DD
# 4  RR, DD, PWI, SRH, MI, GL, KXIP
#
# [4 rows x 13 columns]

# %%
ipl_auction_df[:-5]
# Out:
#     S.No Set No    Set  ... Auctioned Price(in ₹ Lacs)  IPL 2019 Team  \
# 0      1      1    BA1  ...                        200            KKR
# 1      2      1    BA1  ...                        525            NaN
# 2      3      1    BA1  ...                        300            KKR
# 3      4      1    BA1  ...                        150            NaN
# 4      5      1    BA1  ...                        440            NaN
# 5      6      2    AL1  ...                       1075            NaN
# 6      7      2    AL1  ...                        150            NaN
# 7      8      2    AL1  ...                       1550            NaN
# 8      9      2    AL1  ...                        550           KXIP
# 9     10      2    AL1  ...                       1000             DC
# 10    11      3    WK1  ...                        240            NaN
# 11    12      4    FA1  ...                        300             RR
# ...

# %%
ipl_auction_df[['Name', 'Country']]
# Out:
#              Name  Country
# 0      Chris Lynn      NaN
# 1     Eoin Morgan      NaN
# 2   Robin Uthappa      NaN
# 3       Jason Roy      NaN
# 4     Aaron Finch      NaN
# ..            ...      ...
# 57    Lalit Yadav      NaN
# 58  Shahbaz Ahmed      NaN
# 59    Nikhil Naik      NaN
# 60     Tom Curran      NaN
# 61    Isuru Udana      NaN
#
# [62 rows x 2 columns]

# %%
ipl_auction_df.Country.value_counts()
# Out:
# Series([], Name: Country, dtype: int64)

# %%
ipl_auction_df.Country.value_counts(normalize=True)*100
# Out:
# Series([], Name: Country, dtype: float64)

# %%
pd.read_csv('datasets/auto-mpg.csv')
# Out:
#       mpg  cylinders  displacement  ... model year  origin  \
# 0    18.0          8         307.0  ...         70       1
# 1    15.0          8         350.0  ...         70       1
# 2    18.0          8         318.0  ...         70       1
# 3    16.0          8         304.0  ...         70       1
# 4    17.0          8         302.0  ...         70       1
# ..    ...        ...           ...  ...        ...     ...
# 393  27.0          4         140.0  ...         82       1
# 394  44.0          4          97.0  ...         82       2
# 395  32.0          4         135.0  ...         82       1
# 396  28.0          4         120.0  ...         82       1
# 397  31.0          4         119.0  ...         82       1
#
#                       car name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# ...

# %%
autos = pd.read_csv('auto-mpg.csv')
autos.head()
# Out:
#     mpg  cylinders  displacement  ... model year  origin  \
# 0  18.0          8         307.0  ...         70       1
# 1  15.0          8         350.0  ...         70       1
# 2  18.0          8         318.0  ...         70       1
# 3  16.0          8         304.0  ...         70       1
# 4  17.0          8         302.0  ...         70       1
#
#                     car name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino
#
# [5 rows x 9 columns]

# %%
autos.columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','year','origin','name']
autos.head()
# Out:
#     mpg  cylinders  displacement  ... year  origin                       name
# 0  18.0          8         307.0  ...   70       1  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...   70       1          buick skylark 320
# 2  18.0          8         318.0  ...   70       1         plymouth satellite
# 3  16.0          8         304.0  ...   70       1              amc rebel sst
# 4  17.0          8         302.0  ...   70       1                ford torino
#
# [5 rows x 9 columns]

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   year          398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   year          398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB
